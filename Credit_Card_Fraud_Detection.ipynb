# %% [markdown]
# # Credit Card Fraud Detection using Machine Learning
#
# ## Problem Statement
#
# Credit card fraud causes significant financial losses to banks and customers. The objective of this project is to build a machine learning model capable of accurately identifying fraudulent transactions while minimizing false positives.

# %% [markdown]
# ## Dataset
#
# Source: Kaggle Credit Card Fraud Detection Dataset
#
# Number of Records:
# - 284,807 Transactions
#
# Number of Features:
# - 30 Features
#
# Target Variable:
# - Class
#     0 → Legitimate
#     1 → Fraud

# %% [markdown]
# ## Objectives
#
# • Perform data preprocessing
# • Analyze transaction patterns
# • Handle class imbalance using SMOTE
# • Train multiple machine learning models
# • Compare model performance
# • Select the best model

# %% [markdown]
# ## Import Required Libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    roc_curve
)

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.175161e-15  3.384974e-16 -1.379537e-15  2.094852e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.021879e-15  1.494498e-15 -5.620335e-16  1.149614e-16 -2.414189e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df.duplicated().sum()
# Out:
# np.int64(1081)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['Class'].value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
(df['Class'].value_counts(normalize=True) * 100)
# Out:
# Class
# 0    99.83329
# 1     0.16671
# Name: proportion, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
df['Class'].value_counts().plot(kind='bar')

plt.title("Fraud vs Legitimate Transactions")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks([0,1], ['Legitimate (0)', 'Fraud (1)'])


plt.show()

# %%
df['Amount'].describe()
# Out:
# count    283726.000000
# mean         88.472687
# std         250.399437
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.510000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Amount'], bins=100)

plt.title("transaction Amount Distribution")
plt.xlabel("Amount")
plt.ylabel("frequency")

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Time'], bins=1500)

plt.title("Transaction Time Distribution")
plt.xlabel("Time")
plt.ylabel("Frequency")

plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(12,10))

sns.heatmap(df.corr(), cmap='coolwarm')

plt.title("Correlation Heatmap")

plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(x='Class', y='Amount', data=df)

plt.title("Transaction Amount by Class")

plt.show()

# %% [markdown]
# ## Feature Scaling

# %%
x = df.drop('Class', axis=1)
y = df['Class']

# %%
#train-Test-split

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (226980, 30)
# (56746, 30)
# (226980,)
# (56746,)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

x_train['Amount'] = scaler.fit_transform(x_train[['Amount']])
x_test['Amount'] = scaler.fit_transform(x_test[['Amount']])

# %%
x_train['Amount'].describe()
# Out:
# count    2.269800e+05
# mean     7.487965e-17
# std      1.000002e+00
# min     -3.596386e-01
# 25%     -3.364866e-01
# 50%     -2.697972e-01
# 75%     -4.287453e-02
# max      7.962087e+01
# Name: Amount, dtype: float64

# %%
y_train.value_counts()
# Out:
# Class
# 0    226602
# 1       378
# Name: count, dtype: int64

# %% [markdown]
# ## Handling Imbalanced Data (SMOTE)

# %%
pip install imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)

x_train_smote, y_train_smote = smote.fit_resample(x_train, y_train)

# %%
y_train_smote.value_counts()
# Out:
# Class
# 0    226602
# 1    226602
# Name: count, dtype: int64

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(
    random_state=42,
    max_iter=1000
)

# %%
lr.fit(x_train_smote, y_train_smote)
# Out:
# c:\Users\thepr\anaconda3\envs\py314\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_pred_lr = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

print("Accuracy :", accuracy_score(y_test, y_pred_lr))
print("Precision :", precision_score(y_test, y_pred_lr))
print("Recall :", recall_score(y_test, y_pred_lr))
print("F1 score :", f1_score(y_test, y_pred_lr))
# Out:
# Accuracy : 0.9888978958869348
# Precision : 0.11621233859397417
# Recall : 0.8526315789473684
# F1 score : 0.20454545454545456

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_lr)
print(cm)
# Out:
# [[56035   616]
#  [   14    81]]

# %% [markdown]
# ## Model Evaluation

# %%
scaler = StandardScaler()

x_train[['Time', 'Amount']] = scaler.fit_transform(x_train[['Time', 'Amount']])
x_test[['Time', 'Amount']] = scaler.transform(x_test[['Time', 'Amount']])

# %%
lr.fit(x_train_smote, y_train_smote)
# Out:
# c:\Users\thepr\anaconda3\envs\py314\Lib\site-packages\sklearn\linear_model\_logistic.py:599: ConvergenceWarning: lbfgs failed to converge after 1000 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=1000).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=1000, random_state=42)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(5,4))
sns.heatmap(cm,
            annot=True,
            fmt='d',
            cmap='Blues')

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix - Logistic Regression")

plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     56651
#            1       0.12      0.85      0.20        95
#
#     accuracy                           0.99     56746
#    macro avg       0.56      0.92      0.60     56746
# weighted avg       1.00      0.99      0.99     56746

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train_smote, y_train_smote)

y_pred_dt = dt.predict(x_test)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_dt))
print("Precision:", precision_score(y_test, y_pred_dt))
print("Recall   :", recall_score(y_test, y_pred_dt))
print("F1 Score :", f1_score(y_test, y_pred_dt))
# Out:
# Accuracy : 0.9965107672787509
# Precision: 0.04424778761061947
# Recall   : 0.05263157894736842
# F1 Score : 0.04807692307692308

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state = 42, n_estimators = 100)
rf.fit(x_train_smote, y_train_smote)

y_pred_rf = rf.predict(x_test)

# %%
print("Accuracy :", accuracy_score(y_test, y_pred_rf))
print("Precision:", precision_score(y_test, y_pred_rf))
print("Recall   :", recall_score(y_test, y_pred_rf))
print("F1 Score :", f1_score(y_test, y_pred_rf))
# Out:
# Accuracy : 0.9993479716632009
# Precision: 0.9393939393939394
# Recall   : 0.6526315789473685
# F1 Score : 0.7701863354037267

# %% [markdown]
# ## Comparison

# %%
#Logistic regression
lr_accuracy = accuracy_score(y_test, y_pred_lr)
lr_precision = precision_score(y_test, y_pred_lr)
lr_recall = recall_score(y_test, y_pred_lr)
lr_f1 = f1_score(y_test, y_pred_lr)

#Decision tree
dt_accuracy = accuracy_score(y_test, y_pred_dt)
dt_precision = precision_score(y_test, y_pred_dt)
dt_recall = recall_score(y_test, y_pred_dt)
dt_f1 = f1_score(y_test, y_pred_dt)

#Random Forest
rf_accuracy = accuracy_score(y_test, y_pred_rf)
rf_precision = precision_score(y_test, y_pred_rf)
rf_recall = recall_score(y_test, y_pred_rf)
rf_f1 = f1_score(y_test, y_pred_rf)

# %%
comparison = pd.DataFrame({

    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest"
    ],

    "Accuracy": [
        lr_accuracy,
        dt_accuracy,
        rf_accuracy
    ],

    "Precision": [
        lr_precision,
        dt_precision,
        rf_precision
    ],

    "Recall": [
        lr_recall,
        dt_recall,
        rf_recall
    ],

    "F1 Score": [
        lr_f1,
        dt_f1,
        rf_f1
    ]

})

comparison

# %%
comparison.style.highlight_max(
    subset=["Accuracy","Precision","Recall","F1 Score"],
    color="lightgreen"
)
# Out:
# <style type="text/css">
# #T_749ba_row0_col3, #T_749ba_row2_col1, #T_749ba_row2_col2, #T_749ba_row2_col4 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_749ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_749ba_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_749ba_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_749ba_level0_col2" class="col_heading level0 col2" >Precision</th>
#       <th id="T_749ba_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_749ba_level0_col4" class="col_heading level0 col4" >F1 Score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_749ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_749ba_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_749ba_row0_col1" class="data row0 col1" >0.988898</td>
# ...

# %%
comparison.round(4)
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0  Logistic Regression    0.9889     0.1162  0.8526    0.2045
# 1        Decision Tree    0.9965     0.0442  0.0526    0.0481
# 2        Random Forest    0.9993     0.9394  0.6526    0.7702

# %% [markdown]
# ## ROC Curve

# %%
y_prob_rf = rf.predict_proba(x_test)[:,1]

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_prob_rf)
auc = roc_auc_score(y_test, y_prob_rf)

print("AUC score:", auc)
# Out:
# AUC score: 0.9583470910068945

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))

plt.plot(fpr,tpr, label=f"AUC = {auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')

plt.xlabel("False Postive Rate")
plt.ylabel("True Postive Rate")
plt.title("ROC curve - Random Forest")
plt.legend()

plt.show()

# %% [markdown]
# ## Feature Importance

# %%
feature_importance = pd.DataFrame({
    'Feature': x_train.columns,
    'Importance': rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

feature_importance.head(10)
# Out:
#    Feature  Importance
# 14     V14    0.222617
# 10     V10    0.124098
# 12     V12    0.112201
# 4       V4    0.101692
# 17     V17    0.090389
# 3       V3    0.079989
# 11     V11    0.049791
# 16     V16    0.039944
# 2       V2    0.037721
# 9       V9    0.026891

# %%
plt.figure(figsize=(10,6))

plt.barh(
    feature_importance['Feature'][:10],
    feature_importance['Importance'][:10]
)

plt.xlabel("Importance")
plt.title("Top 10 Important Features")

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# ## Save Model

# %%
import joblib

joblib.dump(rf, "random_forest_model.pkl")
# Out:
# ['random_forest_model.pkl']

# %%
model = joblib.load("random_forest_model.pkl")

# %%
sample = x_test.iloc[[0]]

prediction = rf.predict(sample)

print(prediction)
# Out:
# [0]

# %% [markdown]
# # Conclusion
#
# This project developed a machine learning model to detect fraudulent credit card transactions using supervised learning techniques.
#
# After preprocessing the data, handling class imbalance with SMOTE, and training multiple classification models, Random Forest achieved the best overall performance based on Precision, Recall, F1 Score, and ROC-AUC.
#
# This project demonstrates practical skills in:
#
# • Data Cleaning
# • Exploratory Data Analysis
# • Feature Engineering
# • Machine Learning
# • Model Evaluation
# • Fraud Detection
